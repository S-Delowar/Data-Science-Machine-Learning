# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df1 = df.copy(deep=True)
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df1.sex = le.fit_transform(df1[['sex']])
df1.smoker = le.fit_transform(df1[['smoker']])
df1.region = le.fit_transform(df1[['region']])

# %%
df1.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
# Loop for label encoder:

# %%
df2.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
for col in df2.columns:
    if not df2.dtypes[col] == object:
        continue
    else:
        print(col)
        df2[col] = le.fit_transform(df2[col])
# Out:
# sex
# smoker
# region

# %%
df2.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # Ordinal Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal = OrdinalEncoder()

# %%
df3.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df3.sex = ordinal.fit_transform(df3[['sex']])

# %%
df3.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19  0.0  27.900         0    yes  southwest  16884.92400
# 1   18  1.0  33.770         1     no  southeast   1725.55230
# 2   28  1.0  33.000         3     no  southeast   4449.46200
# 3   33  1.0  22.705         0     no  northwest  21984.47061
# 4   32  1.0  28.880         0     no  northwest   3866.85520

# %%
order = df3.smoker.unique()

# %%
order
# Out:
# array(['yes', 'no'], dtype=object)

# %%
ordinal_ = OrdinalEncoder(categories=[order])

# %%
df3.smoker = ordinal_.fit_transform(df3[['smoker']])

# %%
df3.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19  0.0  27.900         0     0.0  southwest  16884.92400
# 1   18  1.0  33.770         1     1.0  southeast   1725.55230
# 2   28  1.0  33.000         3     1.0  southeast   4449.46200
# 3   33  1.0  22.705         0     1.0  northwest  21984.47061
# 4   32  1.0  28.880         0     1.0  northwest   3866.85520

# %%
# Loop for Ordinal Encoder:

# %%
df4.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
for col in df4.columns:
    if not df4[col].dtype == object:
        continue    
    else:
        print(col)
        order = df4[col].unique()
        ordinal = OrdinalEncoder(categories=[order])
        df4[col] = ordinal.fit_transform(df4[[col]])
# Out:
# sex
# smoker
# region

# %%
df4.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     0.0     0.0  16884.92400
# 1   18  1.0  33.770         1     1.0     1.0   1725.55230
# 2   28  1.0  33.000         3     1.0     1.0   4449.46200
# 3   33  1.0  22.705         0     1.0     2.0  21984.47061
# 4   32  1.0  28.880         0     1.0     2.0   3866.85520

# %% [markdown]
# # One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()

# %%
df5.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dummy_sex = pd.get_dummies(df5['sex'])
dummy_sex.head()
# Out:
#    female  male
# 0       1     0
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %%
df5.drop('sex', axis=1, inplace=True)

# %%
df5.head()
# Out:
#    age     bmi  children smoker     region      charges
# 0   19  27.900         0    yes  southwest  16884.92400
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520

# %%
new_df5 = pd.concat([df5, dummy_sex], axis=1)

# %%
new_df5.head()
# Out:
#    age     bmi  children smoker     region      charges  female  male
# 0   19  27.900         0    yes  southwest  16884.92400       1     0
# 1   18  33.770         1     no  southeast   1725.55230       0     1
# 2   28  33.000         3     no  southeast   4449.46200       0     1
# 3   33  22.705         0     no  northwest  21984.47061       0     1
# 4   32  28.880         0     no  northwest   3866.85520       0     1

# %%
dummy_smoker = pd.get_dummies(df5['smoker'], drop_first=True, prefix='smoker')
# drop_first=True => drops "smoker_no" column

# %%
dummy_smoker.head()
# Out:
#    smoker_yes
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df5.drop('smoker', axis=True, inplace=True)

# %%
df5.head()
# Out:
#    age     bmi  children     region      charges
# 0   19  27.900         0  southwest  16884.92400
# 1   18  33.770         1  southeast   1725.55230
# 2   28  33.000         3  southeast   4449.46200
# 3   33  22.705         0  northwest  21984.47061
# 4   32  28.880         0  northwest   3866.85520

# %%
df5_2 = pd.concat([df5, dummy_smoker], axis=1)

# %%
df5_2.head()
# Out:
#    age     bmi  children     region      charges  smoker_yes
# 0   19  27.900         0  southwest  16884.92400           1
# 1   18  33.770         1  southeast   1725.55230           0
# 2   28  33.000         3  southeast   4449.46200           0
# 3   33  22.705         0  northwest  21984.47061           0
# 4   32  28.880         0  northwest   3866.85520           0

# %%
# Loop for One-Hot Encoding:

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
for col in df6.columns:
    if not df6[col].dtype == object:
        continue
    else:
        dummy_col = pd.get_dummies(df6[col], drop_first=True, prefix=col)
        df6.drop(col, axis=1, inplace=True)
        df6 = pd.concat([df6, dummy_col], axis=1)

# %%
df6.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
# Replace Method
df7.sex = df.sex.replace(['male', 'female'], [1,2])

# %%
df7.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    2  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520
