# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Delowar/Data-Science-Machine-Learning/blob/main/DA_Project_Group_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Descriptive Analysis with IPIP Scores (like sheet)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Saddam Sir Data Analytics/group project/IPIP Scores_likes.csv')

# %%
df.head()
# Out:
#                                   Filename    WC    WPS  Qmarks  Unique  \
# 0  A M Tauhidul Karim Drubo_AIUB_likes.txt  1424  16.56     0.0   49.37
# 1        aarif hossain-693654204025796.txt  1461  20.29     0.0   51.33
# 2     Abdul Motalib Shaykat_AIUB_likes.txt  1319  17.59     0.0   47.99
# 3            Abhijit Mondal_AIUB_likes.txt  1475  16.39     0.0   48.34
# 4             abhishek Saha_AIUB_likes.txt  1163  18.76     0.0   49.18
#
#      Dic  Sixltr  funct  pronoun  ppron     i    we   you  shehe  they  ipron  \
# 0  66.01   31.18  34.83     6.95   4.78  1.12  1.76  1.33   0.49  0.07   2.18
# 1  56.61   31.69  30.18     5.48   3.70  0.55  1.37  0.96   0.48  0.34   1.78
# 2  59.44   31.24  31.01     4.32   3.03  0.68  1.29  0.68   0.30  0.08   1.29
# 3  65.36   30.64  35.66     6.58   4.81  0.34  2.17  1.83   0.27  0.20   1.76
# 4  60.19   30.87  31.30     4.90   3.10  0.52  1.20  0.77   0.26  0.34   1.81
#
# ...

# %%
df.shape
# Out:
# (251, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 82 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Filename        251 non-null    object
#  1   WC              251 non-null    int64
#  2   WPS             251 non-null    float64
#  3   Qmarks          251 non-null    float64
#  4   Unique          251 non-null    float64
#  5   Dic             251 non-null    float64
#  6   Sixltr          251 non-null    float64
#  7   funct           251 non-null    float64
#  8   pronoun         251 non-null    float64
#  9   ppron           251 non-null    float64
#  10  i               251 non-null    float64
#  11  we              251 non-null    float64
#  12  you             251 non-null    float64
#  13  shehe           251 non-null    float64
#  14  they            251 non-null    float64
#  15  ipron           251 non-null    float64
#  16  article         251 non-null    float64
# ...

# %%
df.drop('Unnamed: 71', axis=1, inplace=True)

# %%
df.shape
# Out:
# (251, 81)

# %%
df.isnull().sum()
# Out:
# Filename          0
# WC                0
# WPS               0
# Qmarks            0
# Unique            0
# Dic               0
# Sixltr            0
# funct             0
# pronoun           0
# ppron             0
# i                 0
# we                0
# you               0
# shehe             0
# they              0
# ipron             0
# article           0
# verb              0
# auxverb           0
# past              0
# present           0
# future            0
# adverb            0
# preps             0
# conj              0
# negate            0
# quant             0
# number            0
# swear             0
# social            0
# family            0
# friend            0
# humans            0
# affect            0
# posemo            0
# negemo            0
# anx               0
# anger             0
# sad               0
# cogmech           0
# insight           0
# cause             0
# discrep           0
# tentat            0
# certain           0
# ...

# %%
# Statistics Analysis for df dataframe
summary_df = df.describe()
summary_df.loc['skewness'] = df.skew()
summary_df.loc['kurtosis'] = df.kurt()
summary_df.loc['variance'] = df.var()
summary_df.loc['mad'] = df.mad()
summary_df
# Out:
#                     WC         WPS      Qmarks      Unique         Dic  \
# count       251.000000  251.000000  251.000000  251.000000  251.000000
# mean       1234.195219   18.158127    0.006016   51.246295   62.501673
# std         283.127685    2.805974    0.034619    5.196622    5.853709
# min           1.000000    1.000000    0.000000   36.800000    0.000000
# 25%        1175.500000   16.525000    0.000000   48.845000   60.975000
# 50%        1292.000000   17.890000    0.000000   50.680000   63.230000
# 75%        1392.500000   19.600000    0.000000   52.830000   65.490000
# max        1887.000000   31.290000    0.450000  100.000000   73.320000
# skewness     -1.890086    0.339489    9.505124    3.825034   -5.297391
# kurtosis      4.524063    8.651718  111.465536   31.729779   51.903833
# variance  80161.285737    7.873490    0.001198   27.004884   34.265907
# mad         186.951191    1.936512    0.011409    3.035870    3.412662
#
# ...

# %% [markdown]
# # Descriptive Analysis with Big5 personality

# %%
df_big5 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Saddam Sir Data Analytics/group project/big5_values.xlsx')

# %%
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m

# %%
df_big5.shape
# Out:
# (164, 7)

# %%
df_big5.isnull().sum()
# Out:
# Filename             0
# Openness             1
# Conscientiousness    1
# Extraversion         1
# Agreeableness        1
# Neuroticism          1
# Gender               1
# dtype: int64

# %%
df_big5 = df_big5.dropna()

# %%
df_big5.isnull().sum()
# Out:
# Filename             0
# Openness             0
# Conscientiousness    0
# Extraversion         0
# Agreeableness        0
# Neuroticism          0
# Gender               0
# dtype: int64

# %%
df_big5.shape
# Out:
# (163, 7)

# %%
# Statistics Analysis for df_big5 dataframe
summary_df_big5 = df_big5.describe()
summary_df_big5.loc['median'] = df_big5.median()
summary_df_big5.loc['skewness'] = df_big5.skew()
summary_df_big5.loc['kurtosis'] = df_big5.kurt()
summary_df_big5.loc['variance'] = df_big5.var()
summary_df_big5.loc['mad'] = df_big5.mad()
summary_df_big5
# Out:
#             Openness  Conscientiousness  Extraversion  Agreeableness  \
# count     163.000000         163.000000    163.000000     163.000000
# mean        0.632975           0.572920      0.518239       0.647074
# std         0.093571           0.143987      0.097876       0.101804
# min         0.375000           0.194000      0.156000       0.361000
# 25%         0.575000           0.472000      0.469000       0.583000
# 50%         0.650000           0.583000      0.500000       0.639000
# 75%         0.700000           0.667000      0.594000       0.694000
# max         0.875000           0.917000      0.750000       0.944000
# median      0.650000           0.583000      0.500000       0.639000
# skewness   -0.283350          -0.027994     -0.206415       0.053202
# kurtosis   -0.016106          -0.317659      0.761286       0.046033
# variance    0.008755           0.020732      0.009580       0.010364
# mad         0.073877           0.116120      0.075872       0.080374
#
# ...

# %% [markdown]
# ## Outliers

# %%
df.shape
# Out:
# (251, 81)

# %%
df2 = df.drop('Filename', axis=1)

z_scores = np.abs((df2 - df2.mean()) / df2.std())

# Set the threshold for outliers
threshold = 3

# Find the outliers in each column
outliers = z_scores > threshold

# Print the outliers
outliers
# Out:
#         WC    WPS  Qmarks  Unique    Dic  Sixltr  funct  pronoun  ppron  \
# 0    False  False   False   False  False   False  False    False  False
# 1    False  False   False   False  False   False  False    False  False
# 2    False  False   False   False  False   False  False    False  False
# 3    False  False   False   False  False   False  False    False  False
# 4    False  False   False   False  False   False  False    False  False
# 5    False  False   False   False  False   False  False    False  False
# 6    False  False   False   False  False   False  False    False  False
# 7    False  False   False   False  False   False  False    False  False
# 8    False  False   False   False  False   False  False    False  False
# 9    False  False   False   False  False   False  False    False  False
# 10   False  False   False   False  False   False  False    False  False
# 11   False  False   False   False  False   False  False    False  False
# ...

# %%
total_outliers = outliers.sum()
total_outliers = pd.DataFrame(total_outliers)
print('Total Outliers:')
total_outliers.transpose()
# Out:
# Total Outliers:
#    WC  WPS  Qmarks  Unique  Dic  Sixltr  funct  pronoun  ppron  i  we  you  \
# 0   8    4       4       3    3       1      2        2      2  2   1    1
#
#    shehe  they  ipron  article  verb  auxverb  past  present  future  adverb  \
# 0      3     3      3        1     4        3     2        2       2       2
#
#    preps  conj  negate  quant  number  swear  social  family  friend  humans  \
# 0      1     2       5      2       3      8       1       3       3       1
#
#    affect  posemo  negemo  anx  anger  sad  cogmech  insight  cause  discrep  \
# 0       3       3       5    3      5    4        3        2      3        3
#
#    tentat  certain  inhib  incl  excl  percept  see  hear  feel  bio  body  \
# 0       3        2      3     2     3        3    3     4     3    4     4
#
#    health  sexual  ingest  relativ  motion  space  time  work  achieve  \
# 0       1       3       5        2       2      1     4     3        4
#
# ...

# %% [markdown]
# ## Outliers for df_big5

# %%
new_df = df_big5.drop('Filename', axis=1)

z_scores = np.abs((new_df - new_df.mean()) / new_df.std())

# Set the threshold for outliers
threshold = 3

# Find the outliers in each column
outliers = z_scores > threshold

# Print the outliers
# outliers
total_outliers = outliers.sum()
total_outliers = pd.DataFrame(total_outliers)
print('Total Outliers of Big5:')
total_outliers.transpose()
# Out:
# Total Outliers of Big5:
#    Agreeableness  Conscientiousness  Extraversion  Gender  Neuroticism  \
# 0              0                  0             1       0            0
#
#    Openness
# 0         0

# %% [markdown]
# ## Merging two dataframes

# %%
df['First Name'] = df['Filename'].str.split('.').str[0]
df['Name'] = df['First Name'].str.replace('_likes', '')
df.drop('First Name', axis=1, inplace=True)
df.shape
# Out:
# (251, 82)

# %%
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m

# %%
df_big5['First Name'] = df_big5['Filename'].str.split('.').str[0]
df_big5['Name'] = df_big5['First Name'].str.replace('_status', '')
df_big5.drop('First Name', axis=1, inplace=True)
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender  \
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m
#
#                             Name
# 0  A M Tauhidul Karim Drubo_AIUB
# 1            Abhijit Mondal_AIUB
# 2             abhishek Saha_AIUB
# 3    Abir Md Moshiur Rahman_AIUB
# 4         abir Tanzin Adnan_AIUB

# %%
merged_df = pd.merge(df_big5, df, on='Name')

# %%
merged_df.drop(['Filename_x', 'Filename_y'], axis=1, inplace=True)

# %%
cols = merged_df.columns.tolist()
cols = [cols[6]] + cols[0:6] + cols[7:]
merged_df = merged_df[cols]

# %%
merged_df.shape
# Out:
# (157, 87)

# %%
merged_df.head()
# Out:
#                             Name  Openness  Conscientiousness  Extraversion  \
# 0  A M Tauhidul Karim Drubo_AIUB     0.625              0.889         0.469
# 1            Abhijit Mondal_AIUB     0.700              0.722         0.531
# 2             abhishek Saha_AIUB     0.650              0.389         0.562
# 3    Abir Md Moshiur Rahman_AIUB     0.750              0.611         0.531
# 4         abir Tanzin Adnan_AIUB     0.650              0.667         0.500
#
#    Agreeableness  Neuroticism Gender    WC    WPS  Qmarks  Unique    Dic  \
# 0          0.750        0.375      m  1424  16.56     0.0   49.37  66.01
# 1          0.694        0.469      m  1475  16.39     0.0   48.34  65.36
# 2          0.528        0.500      m  1163  18.76     0.0   49.18  60.19
# 3          0.833        0.375      m  1374  17.17     0.0   52.84  63.76
# 4          0.778        0.250      m  1175  15.06     0.0   53.87  61.87
#
# ...

# %% [markdown]
# ## Correlation

# %%
df_big5[['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']].corr(method="pearson")
# Out:
#                    Openness  Conscientiousness  Extraversion  Agreeableness  \
# Openness           1.000000           0.139754      0.490963       0.128373
# Conscientiousness  0.139754           1.000000      0.120655       0.117265
# Extraversion       0.490963           0.120655      1.000000       0.105765
# Agreeableness      0.128373           0.117265      0.105765       1.000000
# Neuroticism       -0.075873          -0.563616     -0.120687      -0.128287
#
#                    Neuroticism
# Openness             -0.075873
# Conscientiousness    -0.563616
# Extraversion         -0.120687
# Agreeableness        -0.128287
# Neuroticism           1.000000

# %%
df_0 = df.iloc[:, 1:71]
df_1 = df.iloc[:, 71:-1]

# %%
df_0.shape
# Out:
# (251, 70)

# %%
df_1.shape
# Out:
# (251, 10)

# %%
from pandas.io.formats.format import decimal
corr_matrix = df.corr(method='pearson')
correlations = corr_matrix.loc[df_0.columns, df_1.columns]
correlations.round(decimals= 3).tail(10)
# Out:
#          Benevolence  Universal  Self-direction  Stimulation  Hedonism  \
# work          -0.008      0.009           0.141        0.024    -0.040
# achieve        0.050      0.018           0.057       -0.011    -0.022
# leisure        0.109      0.081           0.066        0.197     0.144
# home           0.033      0.036           0.000        0.034     0.090
# money          0.005     -0.140          -0.018       -0.127    -0.029
# relig          0.040     -0.019           0.167       -0.085     0.032
# death         -0.101      0.008          -0.007       -0.038    -0.028
# assent        -0.038     -0.079          -0.017       -0.044     0.062
# nonfl          0.084      0.112           0.052        0.076     0.108
# filler         0.073      0.049          -0.042       -0.078     0.063
#
#          Achievement   Power  Security  Conformity  Tradition
# work            0.099  0.008     0.076       0.064      0.111
# achieve         0.056  0.067     0.045       0.036      0.073
# ...

# %%
# Covariance
cov = df.cov()
cov.head()
# Out:
#                   WC        WPS    Qmarks       Unique         Dic  \
# WC      80161.285737  10.070247 -0.623819 -1040.918434  307.260632
# WPS        10.070247   7.873490  0.003072    -4.241676    2.909465
# Qmarks     -0.623819   0.003072  0.001198     0.001558    0.008207
# Unique  -1040.918434  -4.241676  0.001558    27.004884   -9.910286
# Dic       307.260632   2.909465  0.008207    -9.910286   34.265907
#
#             Sixltr       funct    pronoun      ppron         i         we  \
# WC      161.886072  135.470633  16.988240  22.165534 -1.145112  27.399022
# WPS      -0.209537    2.663420   0.982046   0.698739  0.446446   0.032504
# Qmarks   -0.014932   -0.001621   0.004714   0.001173 -0.000316   0.002857
# Unique   -5.147504   -6.114898  -1.724910  -1.334560 -0.447382  -0.554447
# Dic       6.561971   19.045875   4.442418   2.766705  0.135624   1.367926
#
#              you     shehe      they     ipron    article       verb  \
# ...

# %% [markdown]
# # Hypothesis Analysis

# %% [markdown]
# ## Hypothesis - 1

# %% [markdown]
# Null hypothesis (H0): There is no significant difference in mean Big Five scores between males and females.

# %% [markdown]
# Alternative hypothesis (HA): There is a significant difference in mean Big Five scores between males and females.

# %%
data = df_big5.drop(['Filename', 'Name'],  axis=1)
male_data = data[data['Gender'] == 'm']
female_data = data[data['Gender'] == 'f']

# %%
from scipy.stats import zscore, norm

# Perform z-tests to compare the means of each personality trait between males and females
openness_z = (male_data['Openness'].mean() - female_data['Openness'].mean()) / (data['Openness'].std(ddof=1) / len(data)**0.5)
openness_p = 2 * (1 - norm.cdf(abs(openness_z)))
conscientiousness_z = (male_data['Conscientiousness'].mean() - female_data['Conscientiousness'].mean()) / (data['Conscientiousness'].std(ddof=1) / len(data)**0.5)
conscientiousness_p = 2 * (1 - norm.cdf(abs(conscientiousness_z)))
extraversion_z = (male_data['Extraversion'].mean() - female_data['Extraversion'].mean()) / (data['Extraversion'].std(ddof=1) / len(data)**0.5)
extraversion_p = 2 * (1 - norm.cdf(abs(extraversion_z)))
agreeableness_z = (male_data['Agreeableness'].mean() - female_data['Agreeableness'].mean()) / (data['Agreeableness'].std(ddof=1) / len(data)**0.5)
agreeableness_p = 2 * (1 - norm.cdf(abs(agreeableness_z)))
neuroticism_z = (male_data['Neuroticism'].mean() - female_data['Neuroticism'].mean()) / (data['Neuroticism'].std(ddof=1) / len(data)**0.5)
neuroticism_p = 2 * (1 - norm.cdf(abs(neuroticism_z)))

# Print the results
print(f"Openness z-value: {openness_z:.3f}, p-value: {openness_p:.3f}")
print(f"Conscientiousness z-value: {conscientiousness_z:.3f}, p-value: {conscientiousness_p:.3f}")
print(f"Extraversion z-value: {extraversion_z:.3f}, p-value: {extraversion_p:.3f}")
print(f"Agreeableness z-value: {agreeableness_z:.3f}, p-value: {agreeableness_p:.3f}")
print(f"Neuroticism z-value: {neuroticism_z:.3f}, p-value: {neuroticism_p:.3f}")
# Out:
# Openness z-value: 3.110, p-value: 0.002
# Conscientiousness z-value: 3.477, p-value: 0.001
# Extraversion z-value: 0.813, p-value: 0.416
# Agreeableness z-value: 0.016, p-value: 0.987
# Neuroticism z-value: -6.819, p-value: 0.000

# %%
# let the value of significance label ia 0.05
alpha = 0.05
# cases = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
for p_value in [openness_p, conscientiousness_p, extraversion_p, agreeableness_p,  neuroticism_p]:
      if p_value <= alpha:
          print(f"Reject the null hypothesis. H(A) is selected.")
      else:
          print(f"Accept the null hypothesis. H(0) is selected.")
# Out:
# Reject the null hypothesis. H(A) is selected.
# Reject the null hypothesis. H(A) is selected.
# Accept the null hypothesis. H(0) is selected.
# Accept the null hypothesis. H(0) is selected.
# Reject the null hypothesis. H(A) is selected.

# %%
if male_data['Openness'].mean() > female_data['Openness'].mean():
        print("Male has more openness personality than female")
else:
        print("Male has less openness personality than female")

if male_data['Conscientiousness'].mean() > female_data['Conscientiousness'].mean():
        print("Male has more Conscientiousness personality than female")
else:
        print("Male has less Conscientiousness personality than female")

if male_data['Extraversion'].mean() > female_data['Extraversion'].mean():
        print("Male has more Extraversion personality than female")
else:
        print("Male has less Extraversion personality than female")

if male_data['Agreeableness'].mean() > female_data['Agreeableness'].mean():
        print("Male has more Agreeableness personality than female")
else:
        print("Male has less Agreeableness personality than female")

if male_data['Neuroticism'].mean() > female_data['Neuroticism'].mean():
        print("Male has more Neuroticism personality than female")
else:
        print("Male has less Neuroticism personality than female")
# Out:
# Male has more openness personality than female
# Male has more Conscientiousness personality than female
# Male has more Extraversion personality than female
# Male has more Agreeableness personality than female
# Male has less Neuroticism personality than female

# %%
male_data.mean()
# Out:
# Openness             0.637311
# Conscientiousness    0.580379
# Extraversion         0.519424
# Agreeableness        0.647098
# Neuroticism          0.460462
# dtype: float64

# %%
female_data.mean()
# Out:
# Openness             0.614516
# Conscientiousness    0.541161
# Extraversion         0.513194
# Agreeableness        0.646968
# Neuroticism          0.549355
# dtype: float64

# %% [markdown]
# ## Hypothesis - 2

# %% [markdown]
# Null hypothesis (H0): There is a significant relation between words related to anxiety with security.

# %% [markdown]
# Alternative hypothesis (HA): There is no significant relation between words related to anxiety qith security.

# %%
data_hypo_2=df.dropna();
anxiety_data = data_hypo_2['anx']
security_data = data_hypo_2['Security']
# data_hypo_2.isnull().sum()

# %%
#from scipy.stats import zscore, norm
import scipy.stats as stats

r,p_value = stats.pearsonr(anxiety_data, security_data)

print('Correlation coefficient (r):', r)
print('p-value:', p_value)
# Out:
# Correlation coefficient (r): -0.007448924786090892
# p-value: 0.9065226991728874

# %%
# let the value of significance label ia 0.05
alpha = 0.05
if p_value <= alpha:
        print(f"Reject the null hypothesis. H(A) is selected.")
else:
        print(f"Accept the null hypothesis. H(0) is selected.")
# Out:
# Accept the null hypothesis. H(0) is selected.
